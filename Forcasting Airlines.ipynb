# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Forecast Airlines Passengers data set. Prepare a document for each model explaining how many dummy variables you have created and RMSE value for each model. Finally which model you will use for Forecasting.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_excel('Airlines+Data.xlsx')
data
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %%
#Renaming Col

data.rename({'Month':'Date'},axis=1, inplace=True)
data.head()
# Out:
#         Date  Passengers
# 0 1995-01-01         112
# 1 1995-02-01         118
# 2 1995-03-01         132
# 3 1995-04-01         129
# 4 1995-05-01         121

# %% [markdown]
# # EDA

# %%
## Checking Null Values

data.isnull().sum()
# Out:
# Date          0
# Passengers    0
# dtype: int64

# %% [markdown]
# **No Null Values in data**

# %%
## Checking Duplicates

data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Passengers]
# Index: []

# %% [markdown]
# **No Duplicates in data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        96 non-null     datetime64[ns]
#  1   Passengers  96 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.6 KB

# %%
data.describe()
# Out:
#        Passengers
# count   96.000000
# mean   213.708333
# std     71.918216
# min    104.000000
# 25%    156.000000
# 50%    200.000000
# 75%    264.750000
# max    413.000000

# %% [markdown]
# ## Visualization

# %%
data.Passengers.plot(figsize=(12,4))
# Out:
# <AxesSubplot:>

# %%
plt.scatter(data['Date'],data['Passengers'])
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Airline passenger traffic')
plt.show()

# %%
## Lone plot

data['Passengers'].plot(figsize=(20,8),color='green', marker='o')
plt.show()

# %% [markdown]
# **Here we can see there is increasing trend going on.**
# **Number of passengers are increasing with the time**
#
# **Trend and Variance is not constant**
#
# **Hence time series is not stationary**

# %%
# Making Separate Month and Year columns

data_1 = data.copy()

data_1['Date'] = pd.to_datetime(data_1.Date,format='%b-%y')
data_1['Month'] = data_1.Date.dt.strftime('%b')              # Month Extraction
data_1['Year'] = data_1.Date.dt.strftime('%Y')              # Year Extraction

data_1.head()
# Out:
#         Date  Passengers  Passengers_Linear_Interpolation Month  Year
# 0 1995-01-01         112                              112   Jan  1995
# 1 1995-02-01         118                              118   Feb  1995
# 2 1995-03-01         132                              132   Mar  1995
# 3 1995-04-01         129                              129   Apr  1995
# 4 1995-05-01         121                              121   May  1995

# %%
##

# %%
# data = data.assign(Passengers_Linear_Interpolation=data.Passengers.interpolate(method='linear'))
# data[['Passengers_Linear_Interpolation']].plot(figsize=(20, 5))
# plt.grid()
# plt.legend(loc='best')
# plt.title('Airline passenger traffic: Linear interpolation')
# plt.show(block=False)
